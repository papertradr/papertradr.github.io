# %% [markdown]
# # Intraday Implied Volatility

# %%
import pandas as pd
from notebooks.helper_functions import *

# %matplotlib inline
# Out:
# /home/jaewonchoi/anaconda3/envs/RLTrader/lib/python3.8/site-packages/py_lets_be_rational/numba_helper.py:10: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   return jit(*jit_args, **jit_kwargs)(fun)

# %% [markdown]
# ## Downloading py_vollib
#
# Implied volatilty calculation does not have a closed form, hence we need to use an iterative approach. Note that vega (or derivative of black scholes price formula with respect to volatiltiy $\sigma$) is an increasing function with respect to volatilty (i.e. $\sigma$). Therefore, for a given call/put option price, there exists a unique implied volatility. Using this observation, we can use iterative methods such as Newton-Raphson method to find the implied volatility.
#
# However, Newton-Raphson method does not always converge and can give erroneous result for deep in the money options. Many academic research papers tried tackling this problem, the most notable being "Let's be rational" by Peter Jackel. Here we use Jackel's method to compute implied volatilty. Fortunately, there is a python implementation of Jacke's paper which we can install with pip.
# ```bash
# pip3 install py_vollib
# ```
# and in our python code, we can import it:
# ```py
# from py_vollib.black_scholes_merton.implied_volatility import implied_volatility
# ```
# You can find the source code at [here][1] and documentation [here][2]
#
#
# [1]: https://github.com/vollib/py_vollib
# [2]: https://vollib.org/documentation/1.0.3/py-modindex.html

# %% [markdown]
# ## Parameters and Helper Functions

# %%
tz = "Asia/Seoul"
beg_date_pd = pd.to_datetime("2023-05-26").tz_localize(tz).date()
end_date_pd = pd.to_datetime("2023-05-26").tz_localize(tz).date()
beg_time = "09:00:01.0"
end_time = "15:19:59.0"

elw_issue_name = "KOSPI200"
issuer_prefix = "KIS"   # korea investment group 한투
underlying_asset_isin = "KR4101T60006"
r = 0.0375     # continuously compounded risk-free interest rate
q = 0.02       # continuously compounded dividend yield
debug=True

# %%
import pickle

def save_to_pickle(data_list, file_path):
    try:
        with open(file_path, 'wb') as file:
            pickle.dump(data_list, file)
        print("Data has been successfully saved to", file_path)
    except Exception as e:
        print("Error occurred while saving data:", e)

def load_from_pickle(file_path):
    try:
        with open(file_path, 'rb') as file:
            data_list = pickle.load(file)
        return data_list
    except Exception as e:
        print("Error occurred while loading data:", e)
        return None

# %% [markdown]
# ### Fetching data

# %%
for date in pd.date_range(beg_date_pd, end_date_pd):
    date_str = date.strftime("%Y-%m-%d")
    print(date_str)

    # check if the date is a trading date, if not continue
    if not is_trading_date(date_str):
        continue

    elw_data = ELWData(
        date_str, elw_issue_name, issuer_prefix, 
        r=r, q=q,
        underlying_asset_isin=underlying_asset_isin, 
        tz=tz, debug=debug)

    print("call", len(elw_data.call_isins), elw_data.call_isins)
    print("put", len(elw_data.put_isins), elw_data.put_isins)

    elw_marketdepth = ELWMarketdepthData(
        date_str,
        elw_data.call_isins + elw_data.put_isins,
        [elw_data.underlying_asset_isin],
        beg_time=beg_time,
        end_time=end_time,
        tz=tz,
        debug=debug
    )
    
    elw_data.vol_scatter_plot(elw_data.call_vol_surface, elw_data.put_vol_surface)
    elw_data.vol_surface_plot(elw_data.call_vol_surface, elw_data.put_vol_surface)

    call_vol_surfaces = []
    put_vol_surfaces = []
    next_ts = pd.Timestamp(f"{date_str}T09:05:00.0", tz=tz)
    for k, row in enumerate(elw_marketdepth):
        
        if row["isin"] == elw_data.underlying_asset_isin:
            elw_data.update_underlying_price(row["isin"], row["weighted_midprice"], row["system_datetime"])
        else:
            # elw got updated
            elw_data.update_elw(row["isin"], row["weighted_midprice"], row["system_datetime"])

        if row["system_datetime"] > next_ts:
            next_ts += pd.Timedelta(minutes=5)
            call_vol_surfaces.append(elw_data.call_vol_surface.copy())
            put_vol_surfaces.append(elw_data.put_vol_surface.copy())

        if k % 25000 == 0:
            print(f"updating volatility at {row['system_datetime']}...")


# Save the data to a pickle file
save_to_pickle(call_vol_surfaces, "call_vol_surfaces.pkl")
save_to_pickle(put_vol_surfaces, "put_vol_surfaces.pkl")
# Out:
# 2023-05-26
#            isin  base_price  prev_day_closing_price  \
# 0  KR4101T60006       336.0                   336.0
#
#   abbreviated_issue_name_in_en       date
# 0                     F 202306 2023-05-26
# call 255 ['KRA5731EED35', 'KRA5731EDD36', 'KRA5731EGCA6', 'KRA5731EFCA8', 'KRA5731EECA1', 'KRA5731F5CA4', 'KRA5731FZCA3', 'KRA5731GSCA6', 'KRA5731EDCA3', 'KRA5731F4CA7', 'KRA5731FYCA6', 'KRA5731GRCA8', 'KRA5731ECCA5', 'KRA5731F3CA9', 'KRA5731FXCA8', 'KRA5731GQCA0', 'KRA5731EBCA7', 'KRA5731F2CA1', 'KRA5731FWCA0', 'KRA5731GPCA2', 'KRA5731DGD18', 'KRA5731EACA9', 'KRA5731EBD12', 'KRA5731F1CA3', 'KRA5731F6D10', 'KRA5731FVCA2', 'KRA5731GNCA7', 'KRA5731DFD19', 'KRA5731E9CA7', 'KRA5731EAD13', 'KRA5731F0CA5', 'KRA5731F5D11', 'KRA5731FTCA6', 'KRA5731GMCA9', 'KRA5731DED10', 'KRA5731E9D10', 'KRA5731E8CA9', 'KRA5731F4D12', 'KRA5731EZCA6', 'KRA5731FSCA8', 'KRA5731GLCA1', 'KRA5731DDD11', 'KRA5731E7CA1', 'KRA5731E8D11', 'KRA5731EYCA9', 'KRA5731F3D13', 'KRA5731FRCA0', 'KRA5731GKCA3', 'KRA5731DCD12', 'KRA5731E6CA3', 'KRA5731E7D12', 'KRA5731EXCA1', 'KRA5731F2D14', 'KRA5731FQCA2', 'KRA5731GJCA5', 'KRA5731LHC75', 'KRA5731DBD13', 'KRA5731E6D13', 'KRA5731EWCA3', 'KRA5731F1D15', 'KRA5731FPCA4', 'KRA5731GHCA9', 'KRA5731LGC76', 'KRA5731DAD14', 'KRA5731E5D14', 'KRA5731EVCA5', 'KRA5731F0D16', 'KRA5731FNCA9', 'KRA5731GGCA1', 'KRA5731LFC77', 'KRA5731D9D12', 'KRA5731E4D15', 'KRA5731ETCA9', 'KRA5731EZD14', 'KRA5731FMCA1', 'KRA5731GFCA3', 'KRA5731LEC78', 'KRA5731D8D13', 'KRA5731E3D16', 'KRA5731EYD15', 'KRA5731ESCA1', 'KRA5731FLCA3', 'KRA5731GECA6', 'KRA5731LDC79', 'KRA5731D7D14', 'KRA5731E2D17', 'KRA5731EXD16', 'KRA5731ERCA3', 'KRA5731FKCA5', 'KRA5731GDCA8', 'KRA5731LCC70', 'KRA5731D6D15', 'KRA5731E1D18', 'KRA5731EWD17', 'KRA5731EQCA5', 'KRA5731FJCA7', 'KRA5731GCCA0', 'KRA5731CCCB7', 'KRA5731LBC71', 'KRA5731D5D16', 'KRA5731CZCB8', 'KRA5731DKCB8', 'KRA5731E0D19', 'KRA5731EVD18', 'KRA5731ETD12', 'KRA5731LAC72', 'KRA5731CBCB9', 'KRA5731CYCB1', 'KRA5731D4D17', 'KRA5731DJCB0', 'KRA5731DZD15', 'KRA5731L9C73', 'KRA5731CACB1', 'KRA5731D3D18', 'KRA5731CXCB3', 'KRA5731DHCB4', 'KRA5731DYD16', 'KRA5731ESD13', 'KRA5731CWCB5', 'KRA5731L8C74', 'KRA5731C9CB7', 'KRA5731D2D19', 'KRA5731DGCB6', 'KRA5731DXD17', 'KRA5731ERD14', 'KRA5731L7C75', 'KRA5731C8CB9', 'KRA5731CVCB7', 'KRA5731DFCB8', 'KRA5731ECD29', 'KRA5731F9D25', 'KRA5731G6D26', 'KRA5731L6C76', 'KRA5731C7CB1', 'KRA5731CTCB1', 'KRA5731DECB1', 'KRA5731EBD20', 'KRA5731F8D26', 'KRA5731G5D27', 'KRA5731L5C77', 'KRA5731C6CB3', 'KRA5731CSCB3', 'KRA5731DDCB3', 'KRA5731EAD21', 'KRA5731F7D27', 'KRA5731G4D28', 'KRA5731L4C78', 'KRA5731C5CB5', 'KRA5731CRCB5', 'KRA5731DCCB5', 'KRA5731E9D28', 'KRA5731F6D28', 'KRA5731G3D29', 'KRA5731HQD53', 'KRA5731L3C79', 'KRA5731C4CB8', 'KRA5731CQCB7', 'KRA5731DBCB7', 'KRA5731E8D29', 'KRA5731F5D29', 'KRA5731G2D20', 'KRA5731HPD54', 'KRA5731L2C70', 'KRA5731C3CB0', 'KRA5731CPCB9', 'KRA5731DACB9', 'KRA5731E7D20', 'KRA5731F4D20', 'KRA5731G1D21', 'KRA5731HND56', 'KRA5731FFC83', 'KRA5731CCCC5', 'KRA5731CVCC5', 'KRA5731DBCC5', 'KRA5731E6D21', 'KRA5731F3D21', 'KRA5731G0D22', 'KRA5731HMD57', 'KRA5731FEC84', 'KRA5731CBCC7', 'KRA5731CTCC9', 'KRA5731DACC7', 'KRA5731E5D22', 'KRA5731F2D22', 'KRA5731FZD21', 'KRA5731HLD58', 'KRA5731FDC85', 'KRA5731CACC9', 'KRA5731CSCC1', 'KRA5731D9CC4', 'KRA5731E4D23', 'KRA5731F1D23', 'KRA5731FYD22', 'KRA5731HKD59', 'KRA5731FCC86', 'KRA5731C9CC5', 'KRA5731CRCC3', 'KRA5731D8CC6', 'KRA5731E3D24', 'KRA5731F0D24', 'KRA5731FXD23', 'KRA5731FBC87', 'KRA5731C8CC7', 'KRA5731CQCC5', 'KRA5731D7CC8', 'KRA5731E2D25', 'KRA5731EZD22', 'KRA5731FWD24', 'KRA5731FAC88', 'KRA5731C7CC9', 'KRA5731CPCC7', 'KRA5731D6CC0', 'KRA5731E1D26', 'KRA5731EYD23', 'KRA5731FVD25', 'KRA5731F9C83', 'KRA5731C6CC1', 'KRA5731CNCC2', 'KRA5731D5CC2', 'KRA5731E0D27', 'KRA5731EXD24', 'KRA5731FTD29', 'KRA5731F8C84', 'KRA5731C5CC3', 'KRA5731D4CC5', 'KRA5731CMCC4', 'KRA5731DZD23', 'KRA5731EWD25', 'KRA5731FSD20', 'KRA5731DRD23', 'KRA5731F7C85', 'KRA5731DTD21', 'KRA5731DYD24', 'KRA5731DWD26', 'KRA5731EVD26', 'KRA5731FRD21', 'KRA5731DQD24', 'KRA5731FQD22', 'KRA5731F6C86', 'KRA5731DSD22', 'KRA5731DXD25', 'KRA5731DVD27', 'KRA5731ETD20', 'KRA5731E6D54', 'KRA5731EQD56', 'KRA5731FCD51', 'KRA5731E5D55', 'KRA5731EPD57', 'KRA5731H9D54', 'KRA57 ...
# put 239 ['KRA5732GBCA0', 'KRA5732EPCA5', 'KRA5732FHCA9', 'KRA5732H5CA1', 'KRA5732FGCA1', 'KRA5732ENCA0', 'KRA5732GACA2', 'KRA5732H4CA4', 'KRA5732EMCA2', 'KRA5732FFCA3', 'KRA5732G9CA4', 'KRA5732H3CA6', 'KRA5732DWD17', 'KRA5732ELCA4', 'KRA5732EQD14', 'KRA5732FECA6', 'KRA5732FKD19', 'KRA5732G8CA6', 'KRA5732H2CA8', 'KRA5732G7CA8', 'KRA5732DVD18', 'KRA5732EKCA6', 'KRA5732EPD15', 'KRA5732FDCA8', 'KRA5732FJD12', 'KRA5732H1CA0', 'KRA5732DTD12', 'KRA5732END17', 'KRA5732EJCA8', 'KRA5732FHD14', 'KRA5732FCCA0', 'KRA5732G6CA0', 'KRA5732H0CA2', 'KRA5732G5CA2', 'KRA5732DSD13', 'KRA5732EHCA2', 'KRA5732EMD18', 'KRA5732FBCA2', 'KRA5732FGD15', 'KRA5732GZCA9', 'KRA5732GYCA2', 'KRA5732G4CA5', 'KRA5732DRD14', 'KRA5732ELD19', 'KRA5732FFD16', 'KRA5732FACA4', 'KRA5732LZC72', 'KRA5732GXCA4', 'KRA5732F9CA5', 'KRA5732DQD15', 'KRA5732EKD10', 'KRA5732FED17', 'KRA5732G3CA7', 'KRA5732LYC73', 'KRA5732GWCA6', 'KRA5732DPD16', 'KRA5732EJD13', 'KRA5732F8CA7', 'KRA5732FDD18', 'KRA5732G2CA9', 'KRA5732LXC74', 'KRA5732DND18', 'KRA5732GVCA8', 'KRA5732EHD15', 'KRA5732F7CA9', 'KRA5732FCD19', 'KRA5732G1CA1', 'KRA5732LWC75', 'KRA5732DMD19', 'KRA5732GTCA2', 'KRA5732EGD16', 'KRA5732F6CA1', 'KRA5732FBD10', 'KRA5732G0CA3', 'KRA5732LVC76', 'KRA5732DLD10', 'KRA5732DWCB1', 'KRA5732CNCB2', 'KRA5732D9CB5', 'KRA5732EFD17', 'KRA5732FAD11', 'KRA5732LTC70', 'KRA5732DKD11', 'KRA5732DVCB3', 'KRA5732CMCB4', 'KRA5732D8CB7', 'KRA5732EED18', 'KRA5732F9D15', 'KRA5732LSC71', 'KRA5732CLCB6', 'KRA5732DJD14', 'KRA5732DTCB7', 'KRA5732EDD19', 'KRA5732F8D16', 'KRA5732LRC72', 'KRA5732D7CB9', 'KRA5732DHD16', 'KRA5732DSCB9', 'KRA5732D6CB1', 'KRA5732CKCB8', 'KRA5732ECD10', 'KRA5732F7D17', 'KRA5732LQC73', 'KRA5732CJCB0', 'KRA5732DRCB1', 'KRA5732ESD20', 'KRA5732D5CB3', 'KRA5732FPD22', 'KRA5732LPC74', 'KRA5732GLD25', 'KRA5732CHCB4', 'KRA5732DQCB3', 'KRA5732D4CB6', 'KRA5732ERD21', 'KRA5732FND24', 'KRA5732GKD26', 'KRA5732LNC76', 'KRA5732CGCB6', 'KRA5732D3CB8', 'KRA5732EQD22', 'KRA5732DPCB5', 'KRA5732LMC77', 'KRA5732FMD25', 'KRA5732GJD29', 'KRA5732CFCB8', 'KRA5732LLC78', 'KRA5732D2CB0', 'KRA5732DNCB0', 'KRA5732EPD23', 'KRA5732FLD26', 'KRA5732GHD21', 'KRA5732J4D53', 'KRA5732CECB1', 'KRA5732LKC79', 'KRA5732D1CB2', 'KRA5732DMCB2', 'KRA5732END25', 'KRA5732FKD27', 'KRA5732GGD22', 'KRA5732J3D54', 'KRA5732LJC72', 'KRA5732CDCB3', 'KRA5732D0CB4', 'KRA5732DLCB4', 'KRA5732EMD26', 'KRA5732FJD20', 'KRA5732GFD23', 'KRA5732J2D55', 'KRA5732CLCC4', 'KRA5732FQC89', 'KRA5732D3CC6', 'KRA5732DKCC4', 'KRA5732ELD27', 'KRA5732FHD22', 'KRA5732GED24', 'KRA5732FPC80', 'KRA5732CKCC6', 'KRA5732D2CC8', 'KRA5732DJCC6', 'KRA5732EKD28', 'KRA5732FGD23', 'KRA5732GDD25', 'KRA5732FNC82', 'KRA5732CJCC8', 'KRA5732D1CC0', 'KRA5732DHCC0', 'KRA5732EJD21', 'KRA5732FFD24', 'KRA5732GCD26', 'KRA5732FMC83', 'KRA5732CHCC2', 'KRA5732D0CC2', 'KRA5732DGCC2', 'KRA5732EHD23', 'KRA5732FED25', 'KRA5732GBD27', 'KRA5732FLC84', 'KRA5732CGCC4', 'KRA5732CZCC4', 'KRA5732GAD28', 'KRA5732DFCC4', 'KRA5732EGD24', 'KRA5732FDD26', 'KRA5732FKC85', 'KRA5732CFCC6', 'KRA5732CYCC7', 'KRA5732DECC7', 'KRA5732EFD25', 'KRA5732FCD27', 'KRA5732G9D21', 'KRA5732FJC88', 'KRA5732CECC9', 'KRA5732DDCC9', 'KRA5732CXCC9', 'KRA5732EED26', 'KRA5732FBD28', 'KRA5732G8D22', 'KRA5732FHC80', 'KRA5732CDCC1', 'KRA5732G7D23', 'KRA5732CWCC1', 'KRA5732DCCC1', 'KRA5732EDD27', 'KRA5732FAD29', 'KRA5732FGC81', 'KRA5732FSD45', 'KRA5732EVD58', 'KRA5732EMD59', 'KRA5732HSD50', 'KRA5732EQD30', 'KRA5732FRD46', 'KRA5732HRD51', 'KRA5732EPD31', 'KRA5732FQD47', 'KRA5732END33', 'KRA5732FPD48', 'KRA5732EMD34', 'KRA5732FND40', 'KRA5732ELD35', 'KRA5732FMD41', 'KRA5732EKD36', 'KRA5732FLD42', 'KRA5732EFD58', 'KRA5732EED59', 'KRA5732EJD39', 'KRA5732FKD43', 'KRA5732EHD31', 'KRA5732FJD46', 'KRA5732ECD51', 'KRA5732FHD48', 'KRA5732EBD52', 'KRA5732EGD32', 'KRA5732FGD49', 'KRA5732EAD53', 'KRA5732E9D59', 'KRA5732EFD33', 'KRA5732FFD40', 'KRA5732FED41', 'KRA5732E7D51']
# 0.0 0.6515134519412222
# 0.0 0.0
# 0.3616670187783834 0.6515134519412222
# updating volatility at 2023-05-26 09:00:01.045358767+09:00...
# updating volatility at 2023-05-26 09:01:39.411148992+09:00...
# updating volatility at 2023-05-26 09:03:43.643102216+09:00...
# updating volatility at 2023-05-26 09:06:07.981260193+09:00...
# updating volatility at 2023-05-26 09:08:19.876255262+09:00...
# updating volatility at 2023-05-26 09:11:30.103289996+09:00...
# updating volatility at 2023-05-26 09:14:57.690559614+09:00...
# updating volatility at 2023-05-26 09:17:35.337466122+09:00...
# updating volatility at 2023-05-26 09:21:11.689315257+09:00...
# updating volatility at 2023-05-26 09:24:25.026190542+09:00...
# updating volatility at 2023-05-26 09:28:19.984093237+09:00...
# updating volatility at 2023-05-26 09:31:53.165849965+09:00...
# updating volatility at 2023-05-26 09:36:36.249314137+09:00...
# updating volatility at 2023-05-26 09:41:06.107326049+09:00...
# updating volatility at 2023-05-26 09:46:06.690002544+09:00...
# updating volatility at 2023-05-26 09:50:50.302028603+09:00...
# updating volatility at 2023-05-26 09:54:34.031246212+09:00...
# updating volatility at 2023-05-26 09:58:34.285561722+09:00...
# updating volatility at 2023-05-26 10:01:09.901217763+09:00...
# updating volatility at 2023-05-26 10:03:27.913446744+09:00...
# updating volatility at 2023-05-26 10:06:59.153217243+09:00...
# updating volatility at 2023-05-26 10:10:49.208580842+09:00...
# updating volatility at 2023-05-26 10:15:10.312994642+09:00...
# updating volatility at 2023-05-26 10:19:32.652522429+09:00...
# updating volatility at 2023-05-26 10:23:53.865341017+09:00...
# updating volatility at 2023-05-26 10:26:34.919948262+09:00...
# updating volatility at 2023-05-26 10:30:08.128534289+09:00...

# %%
call_vol_surfaces_ld = load_from_pickle("call_vol_surfaces.pkl")
put_vol_surfaces_ld = load_from_pickle("put_vol_surfaces.pkl")

print(call_vol_surfaces_ld[10])
# Out:
# {'KRA5731EED35': {'price': 6985.454545454545, 'exercise_price': 265.0, 'moneyness': 0.7886904761904762, 'maturity': 17, 'sigma': 0}, 'KRA5731EDD36': {'price': 6640.886075949367, 'exercise_price': 270.0, 'moneyness': 0.8035714285714286, 'maturity': 17, 'sigma': 0}, 'KRA5731EGCA6': {'price': 6255.454545454545, 'exercise_price': 272.5, 'moneyness': 0.8110119047619048, 'maturity': 17, 'sigma': 0}, 'KRA5731EFCA8': {'price': 6013.636363636364, 'exercise_price': 275.0, 'moneyness': 0.8184523809523809, 'maturity': 17, 'sigma': 0}, 'KRA5731EECA1': {'price': 5771.818181818182, 'exercise_price': 277.5, 'moneyness': 0.8258928571428571, 'maturity': 17, 'sigma': 0}, 'KRA5731F5CA4': {'price': 5950.0, 'exercise_price': 277.5, 'moneyness': 0.8258928571428571, 'maturity': 52, 'sigma': 0}, 'KRA5731FZCA3': {'price': 6017.5, 'exercise_price': 277.5, 'moneyness': 0.8258928571428571, 'maturity': 80, 'sigma': 0}, 'KRA5731GSCA6': {'price': 6117.5, 'exercise_price': 277.5, 'moneyness': 0.8258928571428571, 'maturity': 115, 'sigma': 0.1697614521530877}, 'KRA5731EDCA3': {'price': 5520.0, 'exercise_price': 280.0, 'moneyness': 0.8333333333333334, 'maturity': 17, 'sigma': 0}, 'KRA5731F4CA7': {'price': 5705.0, 'exercise_price': 280.0, 'moneyness': 0.8333333333333334, 'maturity': 52, 'sigma': 0}, 'KRA5731FYCA6': {'price': 5772.5, 'exercise_price': 280.0, 'moneyness': 0.8333333333333334, 'maturity': 80, 'sigma': 0}, 'KRA5731GRCA8': {'price': 5877.5, 'exercise_price': 280.0, 'moneyness': 0.8333333333333334, 'maturity': 115, 'sigma': 0.1715081023631509}, 'KRA5731ECCA5': {'price': 5278.181818181818, 'exercise_price': 282.5, 'moneyness': 0.8407738095238095, 'maturity': 17, 'sigma': 0}, 'KRA5731F3CA9': {'price': 5455.0, 'exercise_price': 282.5, 'moneyness': 0.8407738095238095, 'maturity': 52, 'sigma': 0}, 'KRA5731FXCA8': {'price': 5525.0, 'exercise_price': 282.5, 'moneyness': 0.8407738095238095, 'maturity': 80, 'sigma': 0}, 'KRA5731GQCA0': {'price': 5642.5, 'exercise_price': 282.5, 'moneyness': 0.8407738095238095, 'maturity': 115, 'sigma': 0.17570921510140208}, 'KRA5731EBCA7': {'price': 5036.818181818182, 'exercise_price': 285.0, 'moneyness': 0.8482142857142857, 'maturity': 17, 'sigma': 0}, 'KRA5731F2CA1': {'price': 5183.743016759777, 'exercise_price': 285.0, 'moneyness': 0.8482142857142857, 'maturity': 52, 'sigma': 0}, 'KRA5731FWCA0': {'price': 5285.0, 'exercise_price': 285.0, 'moneyness': 0.8482142857142857, 'maturity': 80, 'sigma': 0}, 'KRA5731GPCA2': {'price': 5400.0, 'exercise_price': 285.0, 'moneyness': 0.8482142857142857, 'maturity': 115, 'sigma': 0.172054334407744}, 'KRA5731DGD18': {'price': 5200.0, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 143, 'sigma': 0.15868676868721576}, 'KRA5731EACA9': {'price': 4795.0, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 17, 'sigma': 0}, 'KRA5731EBD12': {'price': 5285.0, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 171, 'sigma': 0.16834780062328664}, 'KRA5731F1CA3': {'price': 4873.021582733813, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 52, 'sigma': 0}, 'KRA5731F6D10': {'price': 5430.0, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 206, 'sigma': 0.18343216467846238}, 'KRA5731FVCA2': {'price': 5040.0, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 80, 'sigma': 0}, 'KRA5731GNCA7': {'price': 5077.5, 'exercise_price': 287.5, 'moneyness': 0.8556547619047619, 'maturity': 115, 'sigma': 0}, 'KRA5731DFD19': {'price': 4967.5, 'exercise_price': 290.0, 'moneyness': 0.8630952380952381, 'maturity': 143, 'sigma': 0.1586600450971186}, 'KRA5731E9CA7': {'price': 4558.181818181818, 'exercise_price': 290.0, 'moneyness': 0.8630952380952381, 'maturity': 17, 'sigma': 0}, 'KRA5731EAD13': {'price': 5065.0, 'exercise_price': 290.0, 'moneyness': 0.8630952380952381, 'maturity': 171, 'sigma': 0.169707131088968}, 'KRA5731F0CA5': {'price': 4694.450549450549, 'exercise_price': 290.0, 'moneyness': 0.863095238 ...

# %%
ELWData.vol_scatter_plot(call_vol_surfaces_ld[12], put_vol_surfaces_ld[12])
ELWData.vol_surface_plot(call_vol_surfaces_ld[12], put_vol_surfaces_ld[12])
# Out:
# 0.0 0.18343216467846238
# 0.0 nan
# 0.18343216467846238 nan

# %%
ELWData.vol_scatter_plot(call_vol_surfaces_ld[24], put_vol_surfaces_ld[24])
ELWData.vol_surface_plot(call_vol_surfaces_ld[24], put_vol_surfaces_ld[24])
# Out:
# 0.0 0.18343216467846238
# 0.0 nan
# 0.18343216467846238 nan

# %%
ELWData.vol_scatter_plot(call_vol_surfaces_ld[72], put_vol_surfaces_ld[72])
ELWData.vol_surface_plot(call_vol_surfaces_ld[72], put_vol_surfaces_ld[72])
# Out:
# 0.0 0.18343216467846238
# 0.0 nan
# 0.18343216467846238 nan
